# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# python-dotenv could not parse statement starting at line 7
# python-dotenv could not parse statement starting at line 8
# True

# %%
agent = Agent(name="Jokester", instructions="A comedian who tells jokes", model="gpt-5.2-chat-latest")

# %%
with trace("jokester-agent"):
    result = await Runner.run(agent, "Tell me a joke about computers and pcs.")
    print(result.final_output)
# Out:
# Sure! 😄
#
# Why did the PC go to the doctor?
#
# Because it caught a **virus**… and couldn’t stop **crashing** every time it tried to open up about its *Windows*. 🖥️😂
